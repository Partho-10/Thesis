# %%
import os
import json
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.densenet import preprocess_input
from tensorflow.keras.models import load_model

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix,
    roc_auc_score
)
from tensorflow.keras.utils import to_categorical

sns.set(style="whitegrid")

# %%
BASE_PATH = Path(r"E:\Thesis")

HAM_PATH = BASE_PATH / "HAM10000"
PAD_PATH = BASE_PATH / "PAD-UFES-20"

HAM_IMAGE_DIR = HAM_PATH / "images"
PAD_IMAGE_DIR = PAD_PATH / "images"

CHAR_DIR = BASE_PATH / "outputs" / "dataset_characterization"
MODEL_DIR = BASE_PATH / "outputs" / "densenet201_baseline"

OUT_DIR = BASE_PATH / "outputs" / "brightness_normalization_test"
OUT_DIR.mkdir(parents=True, exist_ok=True)

MODEL_PATH = MODEL_DIR / "best_model.keras"

CLASS_NAMES = ["ACK", "BCC", "MEL", "NEV"]
IMG_SIZE = (250, 250)
BATCH_SIZE = 4

print("Model path:", MODEL_PATH)
print("Output folder:", OUT_DIR)
# Out:
# Model path: E:\Thesis\outputs\densenet201_baseline\best_model.keras
# Output folder: E:\Thesis\outputs\brightness_normalization_test

# %%
summary = pd.read_csv(CHAR_DIR / "dataset_summary.csv")
print(summary[["dataset", "mean_brightness"]])

ham_mean_brightness = float(
    summary.loc[summary["dataset"] == "HAM10000", "mean_brightness"].iloc[0]
)
pad_mean_brightness = float(
    summary.loc[summary["dataset"] == "PAD_UFES_20", "mean_brightness"].iloc[0]
)

brightness_factor = ham_mean_brightness / pad_mean_brightness

print("HAM mean brightness:", ham_mean_brightness)
print("PAD mean brightness:", pad_mean_brightness)
print("Brightness scale factor:", brightness_factor)
# Out:
#        dataset  mean_brightness
# 0     HAM10000       156.864774
# 1  PAD_UFES_20       142.266803
# HAM mean brightness: 156.8647741614629
# PAD mean brightness: 142.26680337604984
# Brightness scale factor: 1.102609817884406

# %%
pad = pd.read_csv(PAD_PATH / "metadata.csv")

PAD_CLASSES = ["ACK", "BCC", "MEL", "NEV"]

pad_4 = pad[pad["diagnostic"].isin(PAD_CLASSES)].copy()
pad_4["label"] = pad_4["diagnostic"]

pad_4["image_path"] = pad_4["img_id"].apply(lambda x: str(PAD_IMAGE_DIR / x))
pad_4["exists"] = pad_4["image_path"].apply(os.path.exists)

print(pad_4["exists"].value_counts())
print(pad_4["label"].value_counts())
# Out:
# exists
# True    1871
# Name: count, dtype: int64
# label
# BCC    845
# ACK    730
# NEV    244
# MEL     52
# Name: count, dtype: int64

# %%
def normalize_brightness_constant(image_path, out_path, factor):
    """
    Multiply all RGB channels by the same constant factor.
    This shifts image brightness while keeping color ratios similar.
    """
    img = Image.open(image_path).convert("RGB")
    arr = np.array(img).astype(np.float32)

    arr = arr * factor
    arr = np.clip(arr, 0, 255).astype(np.uint8)

    Image.fromarray(arr).save(out_path)

# %%
NORMALIZED_DIR = OUT_DIR / "PAD_UFES_20_brightness_normalized_to_HAM"
NORMALIZED_DIR.mkdir(parents=True, exist_ok=True)

normalized_paths = []

for i, row in pad_4.iterrows():
    original_path = row["image_path"]
    filename = os.path.basename(original_path)
    out_path = NORMALIZED_DIR / filename

    if not out_path.exists():
        normalize_brightness_constant(
            image_path=original_path,
            out_path=out_path,
            factor=brightness_factor
        )

    normalized_paths.append(str(out_path))

pad_norm = pad_4.copy()
pad_norm["image_path"] = normalized_paths

print("Normalized images saved:", len(normalized_paths))
print(pad_norm[["img_id", "image_path"]].head())
# Out:
# Normalized images saved: 1871
#                   img_id                                         image_path
# 0  PAT_1516_1765_530.png  E:\Thesis\outputs\brightness_normalization_tes...
# 1     PAT_46_881_939.png  E:\Thesis\outputs\brightness_normalization_tes...
# 2  PAT_1545_1867_547.png  E:\Thesis\outputs\brightness_normalization_tes...
# 3  PAT_1989_4061_934.png  E:\Thesis\outputs\brightness_normalization_tes...
# 4   PAT_684_1302_588.png  E:\Thesis\outputs\brightness_normalization_tes...

# %%
def mean_brightness_from_image(path):
    img = Image.open(path).convert("RGB")
    arr = np.array(img).astype(np.float32)
    luminance = 0.299 * arr[:, :, 0] + 0.587 * arr[:, :, 1] + 0.114 * arr[:, :, 2]
    return float(luminance.mean())

sample_original = pad_4["image_path"].sample(5, random_state=42).tolist()
sample_norm = [str(NORMALIZED_DIR / os.path.basename(p)) for p in sample_original]

for o, n in zip(sample_original, sample_norm):
    print(
        os.path.basename(o),
        "original=", round(mean_brightness_from_image(o), 2),
        "normalized=", round(mean_brightness_from_image(n), 2)
    )
# Out:
# PAT_1571_2484_488.png original= 149.8 normalized= 164.68
# PAT_567_1076_545.png original= 152.43 normalized= 167.2
# PAT_46_880_140.png original= 143.68 normalized= 157.93
# PAT_545_1030_854.png original= 149.6 normalized= 164.46
# PAT_279_429_142.png original= 150.03 normalized= 164.35

# %%
pad_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

pad_original_generator = pad_datagen.flow_from_dataframe(
    dataframe=pad_4,
    x_col="image_path",
    y_col="label",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    classes=CLASS_NAMES,
    shuffle=False
)

pad_norm_generator = pad_datagen.flow_from_dataframe(
    dataframe=pad_norm,
    x_col="image_path",
    y_col="label",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    classes=CLASS_NAMES,
    shuffle=False
)

print("Original PAD samples:", pad_original_generator.samples)
print("Normalized PAD samples:", pad_norm_generator.samples)
# Out:
# Found 1871 validated image filenames belonging to 4 classes.
# Found 1871 validated image filenames belonging to 4 classes.
# Original PAD samples: 1871
# Normalized PAD samples: 1871

# %%
model = load_model(MODEL_PATH)
print("Loaded model:", MODEL_PATH)
# Out:
# Loaded model: E:\Thesis\outputs\densenet201_baseline\best_model.keras

# %%
def evaluate_generator(model, generator):
    loss, acc = model.evaluate(generator, verbose=1)
    probs = model.predict(generator, verbose=1)
    preds = np.argmax(probs, axis=1)
    true = generator.classes
    return loss, acc, probs, preds, true

# %%
orig_loss, orig_acc, orig_probs, orig_preds, orig_true = evaluate_generator(
    model, pad_original_generator
)

print("Original PAD Accuracy:", orig_acc)
print("Original PAD Loss:", orig_loss)
# Out:
# 468/468 [==============================] - 143s 259ms/step - loss: 3.0001 - accuracy: 0.2892
# 468/468 [==============================] - 139s 277ms/step
# Original PAD Accuracy: 0.2891501784324646
# Original PAD Loss: 3.0000996589660645

# %%
norm_loss, norm_acc, norm_probs, norm_preds, norm_true = evaluate_generator(
    model, pad_norm_generator
)

print("Brightness-Normalized PAD Accuracy:", norm_acc)
print("Brightness-Normalized PAD Loss:", norm_loss)
# Out:
# 468/468 [==============================] - 175s 373ms/step - loss: 2.9653 - accuracy: 0.2843
# 468/468 [==============================] - 150s 320ms/step
# Brightness-Normalized PAD Accuracy: 0.28433993458747864
# Brightness-Normalized PAD Loss: 2.965284585952759

# %%
def compute_metrics(true_classes, pred_classes, pred_probs, class_names):
    acc = accuracy_score(true_classes, pred_classes)
    prec = precision_score(true_classes, pred_classes, average="macro", zero_division=0)
    rec = recall_score(true_classes, pred_classes, average="macro", zero_division=0)
    f1 = f1_score(true_classes, pred_classes, average="macro", zero_division=0)

    true_onehot = to_categorical(true_classes, num_classes=len(class_names))
    auc = roc_auc_score(
        true_onehot,
        pred_probs,
        multi_class="ovr",
        average="macro"
    )

    report = classification_report(
        true_classes,
        pred_classes,
        target_names=class_names,
        zero_division=0
    )

    cm = confusion_matrix(true_classes, pred_classes)

    return acc, prec, rec, f1, auc, report, cm

# %%
orig_acc_m, orig_prec, orig_rec, orig_f1, orig_auc, orig_report, orig_cm = compute_metrics(
    orig_true, orig_preds, orig_probs, CLASS_NAMES
)

print("=== Original PAD ===")
print("Accuracy :", orig_acc_m)
print("Precision:", orig_prec)
print("Recall   :", orig_rec)
print("F1 Score :", orig_f1)
print("AUC      :", orig_auc)
print(orig_report)
# Out:
# === Original PAD ===
# Accuracy : 0.28915018706574025
# Precision: 0.29792286744381263
# Recall   : 0.34610476349299785
# F1 Score : 0.21773694454600206
# AUC      : 0.6664067795001829
#               precision    recall  f1-score   support
#
#          ACK       0.28      0.03      0.06       730
#          BCC       0.68      0.34      0.45       845
#          MEL       0.05      0.08      0.06        52
#          NEV       0.18      0.94      0.30       244
#
#     accuracy                           0.29      1871
#    macro avg       0.30      0.35      0.22      1871
# weighted avg       0.44      0.29      0.27      1871

# %%
norm_acc_m, norm_prec, norm_rec, norm_f1, norm_auc, norm_report, norm_cm = compute_metrics(
    norm_true, norm_preds, norm_probs, CLASS_NAMES
)

print("=== Brightness-Normalized PAD ===")
print("Accuracy :", norm_acc_m)
print("Precision:", norm_prec)
print("Recall   :", norm_rec)
print("F1 Score :", norm_f1)
print("AUC      :", norm_auc)
print(norm_report)
# Out:
# === Brightness-Normalized PAD ===
# Accuracy : 0.2843399251737039
# Precision: 0.2838013034599929
# Recall   : 0.342666701658479
# F1 Score : 0.21429768368601942
# AUC      : 0.6680490695112774
#               precision    recall  f1-score   support
#
#          ACK       0.24      0.03      0.06       730
#          BCC       0.67      0.33      0.44       845
#          MEL       0.05      0.08      0.06        52
#          NEV       0.18      0.93      0.30       244
#
#     accuracy                           0.28      1871
#    macro avg       0.28      0.34      0.21      1871
# weighted avg       0.42      0.28      0.26      1871

# %%
comparison = pd.DataFrame({
    "Setting": [
        "Original PAD",
        "Brightness-Normalized PAD"
    ],
    "Accuracy": [orig_acc_m, norm_acc_m],
    "Macro Precision": [orig_prec, norm_prec],
    "Macro Recall": [orig_rec, norm_rec],
    "Macro F1": [orig_f1, norm_f1],
    "Macro AUC": [orig_auc, norm_auc]
})

comparison["F1 Gain"] = comparison["Macro F1"] - orig_f1
comparison["Accuracy Gain"] = comparison["Accuracy"] - orig_acc_m

print(comparison)
comparison.to_csv(OUT_DIR / "comparison.csv", index=False)
# Out:
#                      Setting  Accuracy  Macro Precision  Macro Recall  \
# 0               Original PAD   0.28915         0.297923      0.346105
# 1  Brightness-Normalized PAD   0.28434         0.283801      0.342667
#
#    Macro F1  Macro AUC   F1 Gain  Accuracy Gain
# 0  0.217737   0.666407  0.000000        0.00000
# 1  0.214298   0.668049 -0.003439       -0.00481

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.heatmap(
    orig_cm,
    annot=True,
    fmt="d",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES,
    ax=axes[0]
)
axes[0].set_title("Original PAD")

sns.heatmap(
    norm_cm,
    annot=True,
    fmt="d",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES,
    ax=axes[1]
)
axes[1].set_title("Brightness-Normalized PAD")

for ax in axes:
    ax.set_xlabel("Predicted")
    ax.set_ylabel("Actual")

plt.tight_layout()
plt.savefig(OUT_DIR / "confusion_matrices.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
results_dict = {
    "source_dataset_mean_brightness": ham_mean_brightness,
    "target_dataset_mean_brightness": pad_mean_brightness,
    "brightness_factor": brightness_factor,
    "original_pad": {
        "accuracy": float(orig_acc_m),
        "precision": float(orig_prec),
        "recall": float(orig_rec),
        "f1": float(orig_f1),
        "auc": float(orig_auc)
    },
    "brightness_normalized_pad": {
        "accuracy": float(norm_acc_m),
        "precision": float(norm_prec),
        "recall": float(norm_rec),
        "f1": float(norm_f1),
        "auc": float(norm_auc)
    }
}

with open(OUT_DIR / "results.json", "w") as f:
    json.dump(results_dict, f, indent=2)

print("Saved results.json")
# Out:
# Saved results.json

# %%
pad_norm[["img_id", "label", "image_path"]].to_csv(
    OUT_DIR / "brightness_normalized_pad_paths.csv",
    index=False
)

print("Saved normalized image path mapping.")
# Out:
# Saved normalized image path mapping.

# %%
print("\n--- BRIGHTNESS NORMALIZATION REPORT ---")
print(f"HAM mean brightness: {ham_mean_brightness:.2f}")
print(f"PAD mean brightness: {pad_mean_brightness:.2f}")
print(f"Brightness factor: {brightness_factor:.4f}")
print(f"Original PAD F1: {orig_f1:.4f}")
print(f"Normalized PAD F1: {norm_f1:.4f}")
print(f"F1 gain: {norm_f1 - orig_f1:.4f}")
print(f"Original PAD AUC: {orig_auc:.4f}")
print(f"Normalized PAD AUC: {norm_auc:.4f}")
# Out:
# --- BRIGHTNESS NORMALIZATION REPORT ---
# HAM mean brightness: 156.86
# PAD mean brightness: 142.27
# Brightness factor: 1.1026
# Original PAD F1: 0.2177
# Normalized PAD F1: 0.2143
# F1 gain: -0.0034
# Original PAD AUC: 0.6664
# Normalized PAD AUC: 0.6680
